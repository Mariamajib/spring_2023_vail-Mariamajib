# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/spring_2023_vail-Mariamajib/blob/main/Day_10/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Day 10 Objectives:
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd 
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/' 
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history
  
def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split() 
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1] 
    return " ".join(clean_words) 

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)
    
    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }
    
    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u 
! mkdir input/ 
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))  
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 66.4MB/s]
# mkdir: cannot create directory ‘input/’: File exists
# Epoch 1/20
# 24/24 [==============================] - 5s 148ms/step - loss: 0.8731 - accuracy: 0.6181 - val_loss: 0.7313 - val_accuracy: 0.6745
# Epoch 2/20
# 24/24 [==============================] - 4s 150ms/step - loss: 0.6348 - accuracy: 0.7345 - val_loss: 0.6034 - val_accuracy: 0.7549
# Epoch 3/20
# 24/24 [==============================] - 4s 149ms/step - loss: 0.4891 - accuracy: 0.8189 - val_loss: 0.5506 - val_accuracy: 0.7860
# Epoch 4/20
# 24/24 [==============================] - 4s 148ms/step - loss: 0.3964 - accuracy: 0.8597 - val_loss: 0.5283 - val_accuracy: 0.7891
# Epoch 5/20
# 24/24 [==============================] - 3s 119ms/step - loss: 0.3338 - accuracy: 0.8813 - val_loss: 0.5407 - val_accuracy: 0.7769
# Epoch 6/20
# 24/24 [==============================] - 3s 130ms/step - loss: 0.2872 - accuracy: 0.8996 - val_loss: 0.5540 - val_accuracy: 0.7860
# Epoch 7/20
# 24/24 [==============================] - 4s 177ms/step - loss: 0.2474 - accuracy: 0.9157 - val_loss: 0.5851 - val_accuracy: 0.7693
# Epoch 8/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.2139 - accuracy: 0.9276 - val_loss: 0.6147 - val_accuracy: 0.7739
# Epoch 9/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.1858 - accuracy: 0.9389 - val_loss: 0.6553 - val_accuracy: 0.7656
# Epoch 10/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1618 - accuracy: 0.9483 - val_loss: 0.6879 - val_accuracy: 0.7610
# Epoch 11/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1403 - accuracy: 0.9558 - val_loss: 0.7327 - val_accuracy: 0.7648
# Epoch 12/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.1239 - accuracy: 0.9619 - val_loss: 0.7748 - val_accuracy: 0.7557
# Epoch 13/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1091 - accuracy: 0.9654 - val_loss: 0.8289 - val_accuracy: 0.7564
# Epoch 14/20
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0977 - accuracy: 0.9687 - val_loss: 0.8625 - val_accuracy: 0.7564
# Epoch 15/20
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0853 - accuracy: 0.9734 - val_loss: 0.9032 - val_accuracy: 0.7580
# Epoch 16/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0768 - accuracy: 0.9769 - val_loss: 0.9587 - val_accuracy: 0.7496
# Epoch 17/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0670 - accuracy: 0.9802 - val_loss: 1.0077 - val_accuracy: 0.7519
# Epoch 18/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0609 - accuracy: 0.9824 - val_loss: 1.0452 - val_accuracy: 0.7519
# Epoch 19/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0547 - accuracy: 0.9838 - val_loss: 1.1013 - val_accuracy: 0.7420
# Epoch 20/20
# 24/24 [==============================] - 1s 63ms/step - loss: 0.0486 - accuracy: 0.9852 - val_loss: 1.1461 - val_accuracy: 0.7436
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 2s 77ms/step - loss: 1.0001 - accuracy: 0.6192 - val_loss: 0.9143 - val_accuracy: 0.6586
# Epoch 2/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.8539 - accuracy: 0.6850 - val_loss: 0.8098 - val_accuracy: 0.6935
# Epoch 3/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.7496 - accuracy: 0.7231 - val_loss: 0.7358 - val_accuracy: 0.7269
# Epoch 4/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6682 - accuracy: 0.7591 - val_loss: 0.6817 - val_accuracy: 0.7466
# Epoch 5/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6039 - accuracy: 0.7884 - val_loss: 0.6422 - val_accuracy: 0.7564
# Epoch 6/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.5522 - accuracy: 0.8132 - val_loss: 0.6125 - val_accuracy: 0.7648
# Epoch 7/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.5098 - accuracy: 0.8287 - val_loss: 0.5893 - val_accuracy: 0.7769
# Epoch 8/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4740 - accuracy: 0.8442 - val_loss: 0.5712 - val_accuracy: 0.7800
# Epoch 9/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.4437 - accuracy: 0.8552 - val_loss: 0.5582 - val_accuracy: 0.7822
# Epoch 10/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.4171 - accuracy: 0.8643 - val_loss: 0.5483 - val_accuracy: 0.7891
# Epoch 11/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3942 - accuracy: 0.8723 - val_loss: 0.5425 - val_accuracy: 0.7868
# Epoch 12/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.3742 - accuracy: 0.8781 - val_loss: 0.5376 - val_accuracy: 0.7891
# Epoch 13/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.3562 - accuracy: 0.8854 - val_loss: 0.5345 - val_accuracy: 0.7891
# Epoch 14/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.3403 - accuracy: 0.8902 - val_loss: 0.5331 - val_accuracy: 0.7876
# Epoch 15/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.3257 - accuracy: 0.8940 - val_loss: 0.5333 - val_accuracy: 0.7876
# Epoch 16/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.3121 - accuracy: 0.8986 - val_loss: 0.5335 - val_accuracy: 0.7891
# Epoch 17/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2999 - accuracy: 0.9018 - val_loss: 0.5354 - val_accuracy: 0.7883
# Epoch 18/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.2882 - accuracy: 0.9067 - val_loss: 0.5394 - val_accuracy: 0.7830
# Epoch 19/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.2775 - accuracy: 0.9108 - val_loss: 0.5412 - val_accuracy: 0.7822
# Epoch 20/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.2677 - accuracy: 0.9132 - val_loss: 0.5442 - val_accuracy: 0.7838
# Minimum validation loss reached in epoch 14

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                640064
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 3s 80ms/step - loss: 0.9793 - accuracy: 0.6992 - val_loss: 0.7842 - val_accuracy: 0.7390
# Epoch 2/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.5373 - accuracy: 0.8234 - val_loss: 0.6873 - val_accuracy: 0.7572
# Epoch 3/20
# 24/24 [==============================] - 2s 71ms/step - loss: 0.4200 - accuracy: 0.8789 - val_loss: 0.6705 - val_accuracy: 0.7678
# Epoch 4/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.3496 - accuracy: 0.9108 - val_loss: 0.6870 - val_accuracy: 0.7724
# Epoch 5/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.3032 - accuracy: 0.9308 - val_loss: 0.6946 - val_accuracy: 0.7633
# Epoch 6/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.2719 - accuracy: 0.9469 - val_loss: 0.7183 - val_accuracy: 0.7640
# Epoch 7/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.2454 - accuracy: 0.9588 - val_loss: 0.7177 - val_accuracy: 0.7610
# Epoch 8/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.2272 - accuracy: 0.9647 - val_loss: 0.7511 - val_accuracy: 0.7648
# Epoch 9/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2127 - accuracy: 0.9716 - val_loss: 0.7559 - val_accuracy: 0.7678
# Epoch 10/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.2011 - accuracy: 0.9757 - val_loss: 0.7647 - val_accuracy: 0.7731
# Epoch 11/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.1917 - accuracy: 0.9798 - val_loss: 0.7762 - val_accuracy: 0.7709
# Epoch 12/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1847 - accuracy: 0.9810 - val_loss: 0.7839 - val_accuracy: 0.7527
# Epoch 13/20
# 24/24 [==============================] - 2s 96ms/step - loss: 0.1781 - accuracy: 0.9838 - val_loss: 0.7938 - val_accuracy: 0.7648
# Epoch 14/20
# 24/24 [==============================] - 2s 83ms/step - loss: 0.1725 - accuracy: 0.9847 - val_loss: 0.8085 - val_accuracy: 0.7671
# Epoch 15/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1687 - accuracy: 0.9849 - val_loss: 0.8060 - val_accuracy: 0.7640
# Epoch 16/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.1635 - accuracy: 0.9859 - val_loss: 0.8284 - val_accuracy: 0.7671
# Epoch 17/20
# 24/24 [==============================] - 2s 62ms/step - loss: 0.1602 - accuracy: 0.9874 - val_loss: 0.8066 - val_accuracy: 0.7564
# Epoch 18/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.1554 - accuracy: 0.9878 - val_loss: 0.8134 - val_accuracy: 0.7633
# Epoch 19/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.1521 - accuracy: 0.9890 - val_loss: 0.8311 - val_accuracy: 0.7511
# Epoch 20/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1509 - accuracy: 0.9884 - val_loss: 0.8567 - val_accuracy: 0.7610
# Minimum validation loss reached in epoch 3

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %%
weights = [-5, 4, -3, 2, 1]

def l1_norm(weights):
    reg = tf.reduce_sum(tf.abs(weights))
    return reg

print(l1_norm(weights))
# Out:
# tf.Tensor(15, shape=(), dtype=int32)

# %% [markdown]
# ###  Answer 1
#
# L1 regularization

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg = tf.reduce_sum(tf.square(weights))
    return reg

print(l2_norm(weights))
# Out:
# tf.Tensor(55, shape=(), dtype=int32)

# %% [markdown]
# ###  Answer 2
#
# L2 regularization

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 7s 191ms/step - loss: 0.9381 - accuracy: 0.5905 - val_loss: 0.7891 - val_accuracy: 0.6297
# Epoch 2/20
# 24/24 [==============================] - 3s 132ms/step - loss: 0.7494 - accuracy: 0.6503 - val_loss: 0.6844 - val_accuracy: 0.7086
# Epoch 3/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.6389 - accuracy: 0.7419 - val_loss: 0.6089 - val_accuracy: 0.7686
# Epoch 4/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.5545 - accuracy: 0.7954 - val_loss: 0.5664 - val_accuracy: 0.7853
# Epoch 5/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.4888 - accuracy: 0.8285 - val_loss: 0.5511 - val_accuracy: 0.7898
# Epoch 6/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.4427 - accuracy: 0.8451 - val_loss: 0.5434 - val_accuracy: 0.7860
# Epoch 7/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.4047 - accuracy: 0.8555 - val_loss: 0.5439 - val_accuracy: 0.7807
# Epoch 8/20
# 24/24 [==============================] - 3s 108ms/step - loss: 0.3674 - accuracy: 0.8711 - val_loss: 0.5563 - val_accuracy: 0.7906
# Epoch 9/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.3387 - accuracy: 0.8851 - val_loss: 0.5688 - val_accuracy: 0.7845
# Epoch 10/20
# 24/24 [==============================] - 2s 68ms/step - loss: 0.3130 - accuracy: 0.8942 - val_loss: 0.5789 - val_accuracy: 0.7845
# Epoch 11/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.2886 - accuracy: 0.9017 - val_loss: 0.5839 - val_accuracy: 0.7845
# Epoch 12/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.2700 - accuracy: 0.9094 - val_loss: 0.6057 - val_accuracy: 0.7830
# Epoch 13/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.2512 - accuracy: 0.9153 - val_loss: 0.6139 - val_accuracy: 0.7838
# Epoch 14/20
# 24/24 [==============================] - 2s 69ms/step - loss: 0.2345 - accuracy: 0.9226 - val_loss: 0.6339 - val_accuracy: 0.7853
# Epoch 15/20
# 24/24 [==============================] - 2s 105ms/step - loss: 0.2157 - accuracy: 0.9265 - val_loss: 0.6605 - val_accuracy: 0.7838
# Epoch 16/20
# 24/24 [==============================] - 2s 83ms/step - loss: 0.1959 - accuracy: 0.9335 - val_loss: 0.6789 - val_accuracy: 0.7800
# Epoch 17/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.1908 - accuracy: 0.9398 - val_loss: 0.7036 - val_accuracy: 0.7739
# Epoch 18/20
# 24/24 [==============================] - 1s 63ms/step - loss: 0.1705 - accuracy: 0.9439 - val_loss: 0.7309 - val_accuracy: 0.7724
# Epoch 19/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1647 - accuracy: 0.9477 - val_loss: 0.7465 - val_accuracy: 0.7747
# Epoch 20/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.1522 - accuracy: 0.9517 - val_loss: 0.7713 - val_accuracy: 0.7777
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 12s 437ms/step - loss: nan - accuracy: 0.6095 - val_loss: nan - val_accuracy: 0.6297
# Epoch 2/20
# 24/24 [==============================] - 8s 345ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 3/20
# 24/24 [==============================] - 10s 400ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 4/20
# 24/24 [==============================] - 10s 432ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 5/20
# 24/24 [==============================] - 9s 356ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 6/20
# 24/24 [==============================] - 9s 388ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 7/20
# 24/24 [==============================] - 9s 397ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 8/20
# 24/24 [==============================] - 10s 399ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 9/20
# 24/24 [==============================] - 9s 363ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 10/20
# 24/24 [==============================] - 10s 401ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 11/20
# 24/24 [==============================] - 10s 412ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 12/20
# 24/24 [==============================] - 8s 335ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 13/20
# 24/24 [==============================] - 9s 396ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 14/20
# 24/24 [==============================] - 9s 397ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 15/20
# 24/24 [==============================] - 9s 356ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 16/20
# 24/24 [==============================] - 9s 379ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 17/20
# 24/24 [==============================] - 10s 412ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 18/20
# 24/24 [==============================] - 9s 386ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 19/20
# 24/24 [==============================] - 8s 345ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Epoch 20/20
# 24/24 [==============================] - 10s 411ms/step - loss: nan - accuracy: 0.6269 - val_loss: nan - val_accuracy: 0.6297
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# Dropout should be used when one suspects there are redundant features. A big network will likely have overfitting so, Dropout is usually applied to input and hidden layers. Dropout and regularization are both used to reduce overfitting. Using Dropout requires considering the datasets dimensionality and sparsity alongside the number of datapoints.
#
#
# Adding both L2 regularization and dropout did not uniformly help regularize the data at all

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1551 - accuracy: 0.9625
# Epoch 2/4
# 26/26 [==============================] - 2s 59ms/step - loss: 0.1046 - accuracy: 0.9716
# Epoch 3/4
# 26/26 [==============================] - 2s 72ms/step - loss: 0.0810 - accuracy: 0.9772
# Epoch 4/4
# 26/26 [==============================] - 3s 97ms/step - loss: 0.0667 - accuracy: 0.9815
# 46/46 [==============================] - 0s 5ms/step - loss: 1.0977 - accuracy: 0.7527
#
# Test accuracy: 75.27%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/14
# 26/26 [==============================] - 2s 57ms/step - loss: 0.2870 - accuracy: 0.9038
# Epoch 2/14
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2753 - accuracy: 0.9076
# Epoch 3/14
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2652 - accuracy: 0.9112
# Epoch 4/14
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2554 - accuracy: 0.9155
# Epoch 5/14
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2464 - accuracy: 0.9192
# Epoch 6/14
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2375 - accuracy: 0.9224
# Epoch 7/14
# 26/26 [==============================] - 1s 38ms/step - loss: 0.2296 - accuracy: 0.9248
# Epoch 8/14
# 26/26 [==============================] - 1s 35ms/step - loss: 0.2220 - accuracy: 0.9290
# Epoch 9/14
# 26/26 [==============================] - 1s 38ms/step - loss: 0.2148 - accuracy: 0.9314
# Epoch 10/14
# 26/26 [==============================] - 1s 34ms/step - loss: 0.2078 - accuracy: 0.9344
# Epoch 11/14
# 26/26 [==============================] - 1s 37ms/step - loss: 0.2011 - accuracy: 0.9362
# Epoch 12/14
# 26/26 [==============================] - 1s 41ms/step - loss: 0.1950 - accuracy: 0.9393
# Epoch 13/14
# 26/26 [==============================] - 1s 57ms/step - loss: 0.1891 - accuracy: 0.9408
# Epoch 14/14
# 26/26 [==============================] - 1s 54ms/step - loss: 0.1831 - accuracy: 0.9430
# 46/46 [==============================] - 0s 4ms/step - loss: 0.6174 - accuracy: 0.7760
#
# Test accuracy: 77.60%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/3
# 26/26 [==============================] - 2s 67ms/step - loss: 0.2179 - accuracy: 0.9665
# Epoch 2/3
# 26/26 [==============================] - 2s 64ms/step - loss: 0.1764 - accuracy: 0.9771
# Epoch 3/3
# 26/26 [==============================] - 3s 100ms/step - loss: 0.1627 - accuracy: 0.9826
# 46/46 [==============================] - 0s 5ms/step - loss: 0.7885 - accuracy: 0.7821
#
# Test accuracy: 78.21%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 2s 87ms/step - loss: 0.2091 - accuracy: 0.9345
# Epoch 2/6
# 26/26 [==============================] - 2s 91ms/step - loss: 0.1870 - accuracy: 0.9427
# Epoch 3/6
# 26/26 [==============================] - 2s 63ms/step - loss: 0.1734 - accuracy: 0.9457
# Epoch 4/6
# 26/26 [==============================] - 2s 62ms/step - loss: 0.1606 - accuracy: 0.9511
# Epoch 5/6
# 26/26 [==============================] - 2s 64ms/step - loss: 0.1479 - accuracy: 0.9539
# Epoch 6/6
# 26/26 [==============================] - 2s 63ms/step - loss: 0.1412 - accuracy: 0.9544
# 46/46 [==============================] - 0s 5ms/step - loss: 0.8152 - accuracy: 0.7787
#
# Test accuracy: 77.87%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus question: Plot the same for L1 regularization

# %%
cost = #Enter your code here
l1_penalty = #Enter your code here
cost_plus_l2 = #Enter your code here

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# \<*Type your answer here*\>

# %% [markdown]
# # **Upload this Day 9 Colab Notebook to your Github repository under "Day 9" folder. Also add your *Reflection* on today's learning in README.md**
